# %% [markdown]
# # Ollama를 이용한 LLaMA3 모델 사용

# %%
# !pip install ollama
# Out:
# Requirement already satisfied: ollama in c:\users\playdata\appdata\local\anaconda3\envs\ollama_env\lib\site-packages (0.4.8)
# Requirement already satisfied: httpx<0.29,>=0.27 in c:\users\playdata\appdata\local\anaconda3\envs\ollama_env\lib\site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\users\playdata\appdata\local\anaconda3\envs\ollama_env\lib\site-packages (from ollama) (2.11.3)
# Requirement already satisfied: anyio in c:\users\playdata\appdata\local\anaconda3\envs\ollama_env\lib\site-packages (from httpx<0.29,>=0.27->ollama) (4.9.0)
# Requirement already satisfied: certifi in c:\users\playdata\appdata\local\anaconda3\envs\ollama_env\lib\site-packages (from httpx<0.29,>=0.27->ollama) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\playdata\appdata\local\anaconda3\envs\ollama_env\lib\site-packages (from httpx<0.29,>=0.27->ollama) (1.0.8)
# Requirement already satisfied: idna in c:\users\playdata\appdata\local\anaconda3\envs\ollama_env\lib\site-packages (from httpx<0.29,>=0.27->ollama) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\playdata\appdata\local\anaconda3\envs\ollama_env\lib\site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ollama) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\playdata\appdata\local\anaconda3\envs\ollama_env\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\playdata\appdata\local\anaconda3\envs\ollama_env\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\playdata\appdata\local\anaconda3\envs\ollama_env\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\playdata\appdata\local\anaconda3\envs\ollama_env\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.4.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\playdata\appdata\local\anaconda3\envs\ollama_env\lib\site-packages (from anyio->httpx<0.29,>=0.27->ollama) (1.3.1)

# %% [markdown]
# ### 1. 간단한 질의

# %%
import ollama

# prompt = "Explain AI in simple term"
prompt = "안녕. AI를 한국어로 짧고 간결하게 설명해줘."
response = ollama.generate(model='llama3', prompt=prompt)

response
# Out:
# GenerateResponse(model='llama3', created_at='2025-04-17T05:20:47.300544Z', done=True, done_reason='stop', total_duration=19933843600, load_duration=3462837800, prompt_eval_count=29, prompt_eval_duration=1598763700, eval_count=116, eval_duration=14870830500, response='안녕하세요! 👋\n\nAI(Artificial Intelligence)는 인공지능을 의미합니다. 컴퓨터가 사람과 같은 지능을 가지는 프로그램입니다.\n\nAI는 다음과 같은 기능을 가질 수 있습니다.\n\n* 데이터 분석: 대량의 데이터를 분석하여 필요한 정보를 추출할 수 있습니다.\n* 학습: AI는 데이터에 기반하여 새로운지식을 배울 수 있습니다.\n* decision making: AI는 데이터를 분석하여 결정을 내릴 수 있습니다.\n\n한국어로 짧고 간결하게 설명한 것입니다! 🚀', context=[128006, 882, 128007, 271, 101193, 116024, 13, 15592, 18918, 104008, 32179, 17835, 49011, 100, 35495, 105131, 89881, 102893, 114942, 34983, 59269, 246, 13, 128009, 128006, 78191, 128007, 271, 101193, 124409, 0, 62904, 233, 271, 15836, 83584, 16895, 22107, 114484, 59777, 103896, 67119, 18359, 117460, 61938, 13, 118209, 126692, 20565, 102745, 54780, 105718, 67890, 67119, 18359, 36609, 107054, 113052, 80052, 382, 15836, 16969, 121686, 105718, 117211, 18359, 36609, 103194, 29833, 103924, 382, 9, 55348, 109862, 25, 62060, 104690, 21028, 55348, 18918, 109862, 83290, 126168, 61139, 18918, 58935, 71023, 48936, 29833, 103924, 627, 9, 102533, 36630, 25, 15592, 16969, 55348, 19954, 126470, 83290, 116453, 22035, 118156, 74769, 102275, 29833, 103924, 627, 9, 5597, 3339, 25, 15592, 16969, 55348, 18918, 109862, 83290, 83719, 112813, 67236, 109883, 29833, 103924, 382, 112699, 32179, 17835, 49011, 100, 35495, 105131, 89881, 102893, 114942, 24486, 123263, 0, 11410, 248, 222])

# %%
response['response']
# Out:
# '안녕하세요! 👋\n\nAI(Artificial Intelligence)는 인공지능을 의미합니다. 컴퓨터가 사람과 같은 지능을 가지는 프로그램입니다.\n\nAI는 다음과 같은 기능을 가질 수 있습니다.\n\n* 데이터 분석: 대량의 데이터를 분석하여 필요한 정보를 추출할 수 있습니다.\n* 학습: AI는 데이터에 기반하여 새로운지식을 배울 수 있습니다.\n* decision making: AI는 데이터를 분석하여 결정을 내릴 수 있습니다.\n\n한국어로 짧고 간결하게 설명한 것입니다! 🚀'

# %% [markdown]
# ### 2. 입력 프롬프트에 따른 출력 변화

# %%
prompts = [
    "Explain AI in simple terms.",
    "What is artificial intelligence?",
    "Can you describe how AI works?",
    "Give me a short introduction to artificial intelligence."
]

for prompt in prompts:
    response = ollama.generate(model='llama3', prompt=prompt)
    print("[", prompt, "]")
    print(response['response'])
    print("=" * 100)
# Out:
# [ Explain AI in simple terms. ]
# Artificial Intelligence (AI) is like a super smart computer program that can think and learn like humans do.
#
# Imagine you have a friend who's really good at playing chess. They know all the rules, strategies, and patterns of the game. You can teach them new moves, and they'll get even better over time.
#
# An AI system is similar, but instead of playing chess, it can perform tasks that normally require human intelligence, such as:
#
# 1. **Learning**: AI programs can learn from data, like how your friend learns new chess strategies.
# 2. **Reasoning**: They can make decisions based on that learning, just like your friend makes moves in chess.
# 3. **Problem-solving**: AI systems can solve problems and adapt to new situations, similar to how your friend adjusts their strategy during a game.
#
# But here's the really cool part: AI programs can get better over time by:
#
# * Learning from experiences (like a chess player learning from wins and losses)
# * Improving through data analysis (like a scientist studying patterns in medical data)
#
# In simple terms, AI is like a super smart computer program that can think, learn, reason, and solve problems on its own.
# ====================================================================================================
# [ What is artificial intelligence? ]
# Artificial Intelligence (AI) refers to the development of computer systems that can perform tasks that would typically require human intelligence, such as:
#
# 1. **Learning**: AI systems can learn from data and improve their performance over time.
# 2. **Reasoning**: AI systems can draw conclusions based on given information and apply rules to make decisions.
# 3. **Problem-solving**: AI systems can identify problems and find solutions using algorithms and logic.
#
# AI is a broad field that encompasses various subfields, including:
#
# 1. **Machine Learning** (ML): AI's subset focused on developing algorithms that enable machines to learn from data without being explicitly programmed.
# 2. **Natural Language Processing** (NLP): AI's subset focused on enabling computers to understand, generate, and process human language.
# 3. **Computer Vision**: AI's subset focused on enabling computers to interpret and understand visual information from images and videos.
#
# The goals of AI research are diverse, but some common objectives include:
#
# 1. **Automation**: Automating tasks that are repetitive, time-consuming, or require human judgment.
# 2. **Improved Decision-Making**: Supporting decision-making processes by analyzing data, identifying patterns, and making predictions.
# 3. **Enhanced Customer Experience**: Providing personalized services, recommending products or services based on user behavior, and improving overall customer satisfaction.
# 4. **Scientific Discovery**: Assisting in scientific research by analyzing large datasets, simulating complex systems, and discovering new patterns.
#
# AI has numerous applications across various industries, including:
#
# 1. Healthcare: AI can help diagnose diseases, develop personalized treatment plans, and improve patient outcomes.
# 2. Finance: AI can analyze market trends, detect fraud, and optimize investment strategies.
# 3. Education: AI can personalize learning experiences, provide real-time feedback, and improve student outcomes.
# 4. Manufacturing: AI can streamline production processes, predict maintenance needs, and optimize supply chain management.
#
# In summary, Artificial Intelligence is the development of intelligent systems that can perform tasks that typically require human intelligence, such as learning, reasoning, problem-solving, and decision-making.
# ====================================================================================================
# [ Can you describe how AI works? ]
# Artificial Intelligence (AI) is a broad field that encompasses various techniques and approaches to create intelligent machines that can perform tasks that typically require human intelligence, such as learning, problem-solving, decision-making, and perception.
#
# At its core, AI works by using algorithms and data to enable machines to:
#
# 1. **Learn**: AI systems learn from data, either through supervised or unsupervised learning methods. Supervised learning involves training a model on labeled data, where the correct output is already known. Unsupervised learning, also known as self-organizing, enables the model to discover patterns and relationships in the data without prior knowledge of the correct output.
# 2. **Reason**: AI systems use logical rules and mathematical techniques to reason about the world. This includes using inference, deduction, and abduction to draw conclusions from available information.
# 3. **Perceive**: AI systems can perceive their environment through sensors, such as cameras, microphones, or other devices that gather data about the world.
# 4. **Act**: AI systems take actions based on their perceptions and reasoning. These actions might include generating text, making decisions, controlling robots, or taking other forms of action.
#
# Some common AI techniques include:
#
# 1. **Machine Learning (ML)**: ML is a subset of AI that enables machines to learn from data without being explicitly programmed.
# 2. **Deep Learning (DL)**: DL is a type of machine learning that uses neural networks to analyze and make decisions based on complex patterns in data.
# 3. **Natural Language Processing (NLP)**: NLP is an area of AI that focuses on processing, understanding, and generating human language.
# 4. **Computer Vision**: Computer vision is the study of enabling computers to interpret and understand visual information from the world.
#
# AI systems can be categorized into several types based on their functionality:
#
# 1. **Rule-based Systems**: These systems use predefined rules to make decisions or take actions.
# 2. **Hybrid Systems**: Hybrid AI combines rule-based and machine learning approaches to create more sophisticated decision-making systems.
# 3. **Cognitive Systems**: Cognitive AI aims to replicate human thought processes, such as reasoning, problem-solving, and decision-making.
#
# To achieve its goals, AI relies on various components:
#
# 1. **Data**: AI needs large amounts of high-quality data to learn from, which is often generated through human effort or collected from sensors.
# 2. **Algorithms**: AI algorithms are the underlying logic that enables machines to analyze and process data.
# 3. **Hardware**: AI requires powerful hardware, such as graphics processing units (GPUs) or tensor processing units (TPUs), to perform complex calculations quickly.
# 4. **Software**: AI software is the set of instructions that govern how an AI system operates.
#
# The interplay between these components enables AI systems to learn from data, reason about the world, and take actions based on their understanding.
# ====================================================================================================
# [ Give me a short introduction to artificial intelligence. ]
# Here's a brief introduction to artificial intelligence (AI):
#
# **What is Artificial Intelligence?**
#
# Artificial Intelligence (AI) refers to the development of computer systems that can perform tasks that typically require human intelligence, such as:
#
# * Learning from experience
# * Reasoning and problem-solving
# * Perception, understanding, and interpreting data
#
# In other words, AI enables machines to think and act like humans, but with much greater speed, accuracy, and scalability.
#
# **History of AI**
#
# The concept of AI dates back to the 1950s, when computer scientists like Alan Turing, Marvin Minsky, and John McCarthy explored the possibility of creating machines that could simulate human intelligence. The field gained significant momentum in the 1980s with the development of expert systems, which mimicked human decision-making processes.
#
# **Types of AI**
#
# There are several types of AI, including:
#
# 1. **Narrow or Weak AI**: Designed to perform a specific task, such as facial recognition, speech recognition, or natural language processing.
# 2. **General or Strong AI**: Aims to replicate human intelligence and can learn, reason, and apply knowledge across multiple domains.
# 3. **Superintelligence**: An hypothetical AI that is far more intelligent than humans and could potentially surpass human capabilities.
#
# **Applications of AI**
#
# AI has numerous applications in various fields, including:
#
# 1. **Healthcare**: Medical diagnosis, treatment planning, and personalized medicine
# 2. **Robotics**: Autonomous vehicles, drones, and robots for manufacturing, logistics, and service industries
# 3. **Finance**: Trading, portfolio management, and risk analysis
# 4. **Customer Service**: Chatbots, virtual assistants, and customer support systems
# 5. **Gaming**: Game development, simulation, and augmented reality experiences
#
# **Challenges and Future Directions**
#
# While AI has made significant progress in recent years, there are still many challenges to overcome, such as:
#
# 1. **Explainability**: Understanding how AI models make decisions and predictions
# 2. **Fairness and Bias**: Ensuring AI systems are unbiased and transparent in their decision-making processes
# 3. **Ethics**: Addressing the ethical implications of AI on society, including job displacement and accountability
#
# As AI continues to evolve, we can expect to see even more innovative applications across various industries, leading to new opportunities and challenges for humans.
#
# I hope this introduction gives you a good starting point in understanding artificial intelligence!
# ====================================================================================================

# %% [markdown]
# ### 3. 파라미터 조절

# %%
import ollama

def generate_text_with_params(prompt, max_length=50, temperature=0.7, top_p=1):
    print(f"[Prompt: {prompt} | max_length({max_length}), temperature({temperature}), top_p({top_p})]")

    response = ollama.generate(
        model="llama3",
        prompt=prompt,
        options={
            "max_length": max_length,
            "temperature": temperature,
            "top_p": top_p
        }
    )

    print(response['response'])

# %%
prompt = "오늘 저녁 메뉴 추천해줘"

max_lengths = [20, 50, 100]
temperatures = [0.3, 1.2]

for max_length in max_lengths:
    for temperature in temperatures:
        generate_text_with_params(prompt, max_length, temperature, top_p=1)
        print("=" * 100)
# Out:
# [Prompt: 오늘 저녁 메뉴 추천해줘 | max_length(20), temperature(0.3), top_p(1)]
# I'd be happy to recommend a dinner menu for you today! 😊 Here are a few options:
#
# **Option 1: Korean-Style BBQ**
#
# * Marinated beef short ribs (galbi) with a sweet and spicy sauce
# * Stir-fried vegetables (zucchini, bell peppers, onions)
# * Steamed rice
#
# **Option 2: Italian-Inspired**
#
# * Homemade spaghetti with garlic shrimp and cherry tomatoes
# * Roasted chicken breast with herbs and lemon
# * Garlic bread with melted mozzarella cheese
#
# **Option 3: Asian Fusion**
#
# * Pan-seared salmon with a sweet soy glaze
# * Stir-fried noodles (udon) with vegetables (broccoli, carrots, bell peppers)
# * Steamed edamame and sesame seeds
#
# Which one of these options sounds appealing to you? 🤔
# ====================================================================================================
# [Prompt: 오늘 저녁 메뉴 추천해줘 | max_length(20), temperature(1.2), top_p(1)]
# Today's dinner menu recommendation!
#
# There are many delicious options to consider, but I'll suggest a few ideas:
#
# 🍺 **Bulgogi Beef Noodles**: A classic Korean dish with tender beef marinated in soy sauce, garlic, and sugar, served with chewy noodles.
#
# 🥘 **Crab Rangoon Creamy Pasta**: A creamy pasta dish with crab rangoon filling (crab and cream cheese mix), cherry tomatoes, and basil.
#
# 🍲 **Korean-Style Fried Chicken Tenders**: Crispy fried chicken tenders flavored with Korean chili flakes and soy sauce, served with a side of spicy Gochujang dipping sauce.
#
# 🐟 **Grilled Salmon with Lemon-Herb Butter**: A flavorful salmon fillet grilled to perfection with a sweet and tangy lemon-herb butter glaze.
#
# 🌮 **Vegetarian Quesadilla**: A warm tortilla filled with roasted vegetables (bell peppers, zucchini, and mushrooms), melted cheese, and a hint of cumin. Serve with sour cream or guacamole.
#
# Which of these menu options catches your eye? Do you have any dietary restrictions or preferences I can take into account for the recommendation? 🤔
# ====================================================================================================
# [Prompt: 오늘 저녁 메뉴 추천해줘 | max_length(50), temperature(0.3), top_p(1)]
# I'd be happy to recommend a dinner menu for you! 😊 Here are some options:
#
# **Option 1: Comfort Food**
#
# * Grilled Chicken Parmesan with spaghetti and marinara sauce
# * Garlic bread on the side
# * Fresh fruit salad for dessert
#
# **Option 2: Asian-Inspired**
#
# * Stir-fried noodles with vegetables (e.g., bell peppers, carrots, broccoli) and your choice of protein (chicken, beef, tofu)
# * Steamed edamame as a side dish
# * Mango sorbet for dessert
#
# **Option 3: Mediterranean Delight**
#
# * Grilled salmon with lemon and herbs
# * Roasted vegetables (e.g., zucchini, eggplant, red bell pepper) with olive oil and garlic
# * Warm pita bread with hummus and olives on the side
# * Greek yogurt with honey and walnuts for dessert
#
# **Option 4: Latin Fiesta**
#
# * Beef or chicken fajitas with sautéed onions and bell peppers
# * Warm flour tortillas, sour cream, and salsa on the side
# * Mexican street corn (grilled corn with mayonnaise, cotija cheese, and chili powder) as a side dish
# * Churros with chocolate sauce for dessert
#
# Which option sounds appealing to you? 🤔
# ====================================================================================================
# [Prompt: 오늘 저녁 메뉴 추천해줘 | max_length(50), temperature(1.2), top_p(1)]
# Today's dinner recommendations! 😋 Here are a few ideas:
#
# **Option 1: Comfort Food**
# * Grilled chicken breast with roasted vegetables (e.g., carrots, broccoli, brown rice) and creamy mashed potatoes.
# * Hearty beef stew with crusty bread and a side of fresh green salad.
#
# **Option 2: Quick & Easy**
# * One-pan pasta with ground turkey, tomato sauce, and sautéed bell peppers. Serve with garlic bread and a simple mixed greens salad.
# * Tacos! Use pre-cooked ground beef or chicken, add your favorite toppings (beans, cheese, lettuce, tomatoes), and serve with warm flour tortillas.
#
# **Option 3: International Flair**
# * Korean-style BBQ beef bowl with sticky rice, roasted sweet potatoes, and kimchi.
# * Vegetable-filled quesadilla with guacamole, pico de gallo, and a side of mixed berries.
#
# Which one appeals to you? 🤔
# ====================================================================================================
# [Prompt: 오늘 저녁 메뉴 추천해줘 | max_length(100), temperature(0.3), top_p(1)]
# I'd be happy to recommend a dinner menu for you! 😊
#
# Considering it's a lovely evening, I'll suggest some dishes that are perfect for a cozy night in. Here are three options:
#
# **Option 1: Korean-Style BBQ Beef with Rice and Kimchi**
#
# * Marinated beef short ribs grilled to perfection
# * Served with steaming hot rice and spicy kimchi (Korean fermented cabbage)
# * A classic Korean combination that's easy to make and packed with flavor
#
# **Option 2: Baked Salmon with Lemon-Herb Quinoa and Roasted Vegetables**
#
# * Fresh salmon fillet baked with a zesty lemon-herb butter
# * Paired with quinoa cooked with lemon juice, olive oil, and herbs like thyme and parsley
# * Roasted vegetables (such as broccoli, carrots, and Brussels sprouts) add a pop of color and crunch
#
# **Option 3: Hearty Chicken Fajitas with Sauteed Onions and Bell Peppers**
#
# * Sizzling chicken breast cooked with sliced onions and bell peppers in a savory tomato-based sauce
# * Serve with warm flour tortillas, sour cream, and shredded cheese for a satisfying meal
#
# Which one of these options sounds appealing to you? 🤔
# ====================================================================================================
# [Prompt: 오늘 저녁 메뉴 추천해줘 | max_length(100), temperature(1.2), top_p(1)]
# What a great request! 🍴 Here are some dinner menu recommendations for you:
#
# **Option 1: Flavorful Stir-Fry**
#
# * Korean-style beef and vegetable stir-fry with a sweet soy sauce
# * Sauteed vegetables: bell peppers, carrots, broccoli, and mushrooms
# * Serve with steamed rice or noodles
#
# **Option 2: Global Fusion**
#
# * Grilled chicken Fajita with sautéed onions, bell peppers, and garlic
# * Served with warm flour tortillas, sour cream, and salsa
# * Offer some crispy corn chips on the side for added crunch!
#
# **Option 3: Comfort Food Classic**
#
# * Hearty beef stew made with chunks of beef, potatoes, carrots, and peas in a rich broth
# * Served with crusty bread or over mashed potatoes
#
# **Or get creative with...**
#
# * One-pot pasta bake with marinara sauce, ground beef, and mixed vegetables
# * Quesadillas stuffed with shredded chicken, cheese, and sautéed onions
# * Bento boxes for a quick and easy meal with grilled chicken, steamed rice, and stir-fried vegetables
#
# Which option sounds appealing to you? Or feel free to modify to fit your taste preferences! 😊
# ====================================================================================================
