# %% [markdown]
# # RNN by Tensorflow

# %% [markdown]
# ### 데이터 준비

# %%
VOCAB_SIZE = 300
SEQ_LEN = 100

# %%
from tensorflow.keras.datasets import imdb

(train_input, train_target), (test_input, test_target) = imdb.load_data(num_words=VOCAB_SIZE)
train_input.shape, train_target.shape, test_input.shape, test_target.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ((25000,), (25000,), (25000,), (25000,))

# %%
train_input, test_input = train_input[:10000], test_input[:5000]
train_target, test_target = train_target[:10000], test_target[:5000]
train_input.shape, train_target.shape, test_input.shape, test_target.shape
# Out:
# ((10000,), (10000,), (5000,), (5000,))

# %%
# padding 처리 (동일한 길이)
from tensorflow.keras.preprocessing.sequence import pad_sequences

train_seq = pad_sequences(train_input, maxlen=SEQ_LEN)
test_seq = pad_sequences(test_input, maxlen=SEQ_LEN)

train_seq.shape, test_seq.shape
# Out:
# ((10000, 100), (5000, 100))

# %%
# one-hot encoding
from tensorflow.keras.utils import to_categorical

train_onehot = to_categorical(train_seq)
test_onehot = to_categorical(test_seq)

train_onehot.shape, test_onehot.shape
# Out:
# ((10000, 100, 300), (5000, 100, 300))

# %% [markdown]
# ### 모델 준비 및 학습

# %%
from tensorflow.keras import models, layers, callbacks, optimizers

input = layers.Input(shape=(SEQ_LEN, VOCAB_SIZE))
x = layers.SimpleRNN(units=8)(input)
output = layers.Dense(1, activation='sigmoid')(x)

model = models.Model(input, output)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 100, 300)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn (SimpleRNN)               │ (None, 8)                   │           2,472 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,481 (9.69 KB)
#  Trainable params: 2,481 (9.69 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 컴파일 및 학습
import pandas as pd
import matplotlib.pyplot as plt

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

early_stopping_cb = callbacks.EarlyStopping(patience=7, restore_best_weights=True, verbose=1)
reduce_lr_on_plateau_cb = callbacks.ReduceLROnPlateau(patience=3, factor=0.7, verbose=1)

history = model.fit(
    train_onehot,
    train_target,
    epochs=100,
    batch_size=65,
    validation_split=0.2,
    callbacks=[early_stopping_cb, reduce_lr_on_plateau_cb]
)

history_df = pd.DataFrame(history.history)
history_df.plot()
plt.show()
# Out:
# Epoch 1/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - accuracy: 0.7790 - loss: 0.4740 - val_accuracy: 0.7465 - val_loss: 0.5339 - learning_rate: 0.0010
# Epoch 2/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.7907 - loss: 0.4611 - val_accuracy: 0.7395 - val_loss: 0.5415 - learning_rate: 0.0010
# Epoch 3/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.7763 - loss: 0.4720 - val_accuracy: 0.7345 - val_loss: 0.5346 - learning_rate: 0.0010
# Epoch 4/100
# 122/124 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7901 - loss: 0.4636
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.7902 - loss: 0.4634 - val_accuracy: 0.7400 - val_loss: 0.5484 - learning_rate: 0.0010
# Epoch 5/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.7934 - loss: 0.4547 - val_accuracy: 0.7510 - val_loss: 0.5314 - learning_rate: 7.0000e-04
# Epoch 6/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - accuracy: 0.7885 - loss: 0.4518 - val_accuracy: 0.7480 - val_loss: 0.5345 - learning_rate: 7.0000e-04
# Epoch 7/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.8052 - loss: 0.4366 - val_accuracy: 0.7445 - val_loss: 0.5473 - learning_rate: 7.0000e-04
# Epoch 8/100
# 122/124 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8117 - loss: 0.4292
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0004900000232737511.
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.8115 - loss: 0.4294 - val_accuracy: 0.7385 - val_loss: 0.5448 - learning_rate: 7.0000e-04
# Epoch 9/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.8061 - loss: 0.4299 - val_accuracy: 0.7380 - val_loss: 0.5444 - learning_rate: 4.9000e-04
# Epoch 10/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.8100 - loss: 0.4286 - val_accuracy: 0.7435 - val_loss: 0.5374 - learning_rate: 4.9000e-04
# Epoch 11/100
# 123/124 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8176 - loss: 0.4200
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00034300000406801696.
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.8176 - loss: 0.4201 - val_accuracy: 0.7460 - val_loss: 0.5393 - learning_rate: 4.9000e-04
# Epoch 12/100
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.8136 - loss: 0.4198 - val_accuracy: 0.7395 - val_loss: 0.5471 - learning_rate: 3.4300e-04
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 5.

# %%
loss, accuracy = model.evaluate(test_onehot, test_target)
loss, accuracy
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7225 - loss: 0.5715
# (0.5749491453170776, 0.7202000021934509)
