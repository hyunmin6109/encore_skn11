# %% [markdown]
# - 비선형 지도학습 분류
# 1. Random Forest
# 2. KNN (k-최근접 이웃)
# 3. SVC (RBF 커널)
# 4. XGBoost / LightGBM
# 5. MLP (다층 퍼셉트론)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('./data/online_retail_customer_churn.csv')

# %%
def drop_feature(df):
    return df.drop('Customer_ID', axis=1)

def gender_processed(df):
    df_gender_processed = df.copy()

# 'Other'를 정확히 반반으로 나누어 'Male' / 'Female'로 분산
    other_idx = df_gender_processed[df_gender_processed['Gender'] == 'Other'].index
    half = len(other_idx) // 2
    df_gender_processed.loc[other_idx[:half], 'Gender'] = 'Male'
    df_gender_processed.loc[other_idx[half:], 'Gender'] = 'Female'

    return df_gender_processed

def remove_gender_other(df):
    """Gender가 'Other'인 행 제거"""
    df_cleaned = df[df['Gender'] != 'Other'].copy()
    return df_cleaned



def encode_feature(df):
    # 원핫 인코딩 대상 컬럼
    category = ['Gender', 'Email_Opt_In', 'Promotion_Response']
    
    # 원핫 인코딩 적용 (drop_first=True는 다중공선성 회피용, 상황에 따라 False로 해도 OK)
    df_encoded = pd.get_dummies(df, columns=category, drop_first=True)
    
    return df_encoded


def scale_feature(train_data, test_data):

    sc = StandardScaler()
    # sc = MinMaxScaler()

    train_scaled = sc.fit_transform(train_data)
    test_scaled = sc.transform(test_data)

    return train_scaled, test_scaled

def preprocess_data(df):
    df = drop_feature(df)
    # df = gender_processed(df)
    df = remove_gender_other(df)
    df = encode_feature(df)

    return df

# %%
rt_df = preprocess_data(df)

# %%
rt_df.head()
# Out:
#     Age  Annual_Income  Total_Spend  Years_as_Customer  Num_of_Purchases  \
# 1    65          79.51      9025.47                 13                77
# 2    18          29.19       618.83                 13                71
# 5    57         190.43       255.19                 19                85
# 6    27         172.13      3512.55                  3                77
# 10   54         138.90      4283.84                 15                33
#
#     Average_Transaction_Amount  Num_of_Returns  Num_of_Support_Contacts  \
# 1                        22.90               2                        2
# 2                        50.53               5                        2
# 5                       417.78               5                        1
# 6                       316.18               0                        3
# 10                       96.55               9                        1
#
#     Satisfaction_Score  Last_Purchase_Days_Ago  Target_Churn  Gender_Male  \
# 1                    3                     227         False         True
# 2                    2                     283          True         True
# 5                    4                     130         False         True
# 6                    1                      61         False         True
# 10                   2                      92         False         True
#
#     Email_Opt_In_True  Promotion_Response_Responded  \
# 1               False                          True
# 2               False                          True
# 5               False                         False
# 6                True                         False
# 10               True                          True
#
#     Promotion_Response_Unsubscribed
# 1                             False
# 2                             False
# 5                              True
# 6                              True
# 10                            False

# %%
rt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 676 entries, 1 to 998
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Age                              676 non-null    int64
#  1   Annual_Income                    676 non-null    float64
#  2   Total_Spend                      676 non-null    float64
#  3   Years_as_Customer                676 non-null    int64
#  4   Num_of_Purchases                 676 non-null    int64
#  5   Average_Transaction_Amount       676 non-null    float64
#  6   Num_of_Returns                   676 non-null    int64
#  7   Num_of_Support_Contacts          676 non-null    int64
#  8   Satisfaction_Score               676 non-null    int64
#  9   Last_Purchase_Days_Ago           676 non-null    int64
#  10  Target_Churn                     676 non-null    bool
#  11  Gender_Male                      676 non-null    bool
#  12  Email_Opt_In_True                676 non-null    bool
#  13  Promotion_Response_Responded     676 non-null    bool
#  14  Promotion_Response_Unsubscribed  676 non-null    bool
# dtypes: bool(5), float64(3), int64(7)
# memory usage: 61.4 KB

# %%
rt_df['Target_Churn'].value_counts()
# Out:
# Target_Churn
# True     348
# False    328
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.combine import SMOTETomek

# 1. X, y 분리
X = rt_df.drop('Target_Churn', axis=1)
y = rt_df['Target_Churn'].astype(int)

# 2. train/test 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0, stratify=y)

# 3. 수치형 변수만 스케일링
numeric_cols = X_train.select_dtypes(include=['int64', 'float64']).columns

sc = StandardScaler()
X_scaled_train = X_train.copy()
X_scaled_test = X_test.copy()

X_scaled_train[numeric_cols] = sc.fit_transform(X_train[numeric_cols])
X_scaled_test[numeric_cols] = sc.transform(X_test[numeric_cols])

# ✅ 4. SMOTETomek 적용
from imblearn.combine import SMOTETomek

smt = SMOTETomek(random_state=42)
X_train_resampled, y_train_resampled = smt.fit_resample(X_scaled_train, y_train)

print("SMOTETomek 전:", X_scaled_train.shape, y_train.shape)
print("SMOTETomek 후:", X_train_resampled.shape, y_train_resampled.shape)
# Out:
# SMOTETomek 전: (473, 14) (473,)
# SMOTETomek 후: (386, 14) (386,)

# %%
# !pip install imblearn

# %% [markdown]
# - RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# 최종 모델 학습 (SMOTETomek 적용된 데이터 사용)
rf = RandomForestClassifier(
    n_estimators=80,
    max_depth=3,
    random_state=42,
    class_weight='balanced'  # 클래스 불균형 보정
)
rf.fit(X_train_resampled, y_train_resampled)

# 평가
print(f'훈련 데이터 정확도: {rf.score(X_train_resampled, y_train_resampled):.3f}')
print(f'테스트 데이터 정확도: {rf.score(X_scaled_test, y_test):.3f}')

y_pred_rf = rf.predict(X_scaled_test)
print("\n[RandomForest 분류 리포트]")
print(classification_report(y_test, y_pred_rf))
# Out:
# 훈련 데이터 정확도: 0.764
# 테스트 데이터 정확도: 0.522
#
# [RandomForest 분류 리포트]
#               precision    recall  f1-score   support
#
#            0       0.50      0.56      0.53        98
#            1       0.54      0.49      0.51       105
#
#     accuracy                           0.52       203
#    macro avg       0.52      0.52      0.52       203
# weighted avg       0.52      0.52      0.52       203

# %%
import optuna
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import classification_report
import numpy as np

# 목적 함수 정의
def objective(trial):
    model = RandomForestClassifier(
        n_estimators=trial.suggest_int("n_estimators", 50, 150),
        max_depth=trial.suggest_int("max_depth", 2, 7),
        min_samples_split=trial.suggest_int("min_samples_split", 10, 40),
        min_samples_leaf=trial.suggest_int("min_samples_leaf", 5, 30),
        max_leaf_nodes=trial.suggest_int("max_leaf_nodes", 10, 50),
        max_features=trial.suggest_categorical("max_features", ["sqrt", "log2"]),
        max_samples=trial.suggest_float("max_samples", 0.5, 0.9),
        bootstrap=True,
        random_state=42,
        n_jobs=-1
    )

    # StratifiedKFold로 클래스 비율 유지
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    # score = cross_val_score(model, X_train_oversampled, y_train_oversampled, scoring="f1", cv=cv)
    score = cross_val_score(
    model,
    X_train_resampled, y_train_resampled,
    scoring="balanced_accuracy",  # 또는 'recall'
    cv=cv
)

    return score.mean()



# Optuna 스터디 실행
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=200)

# 최적 파라미터로 모델 학습
print("Best trial parameters:")
print(study.best_trial.params)

best_params = study.best_trial.params
# best_rf = RandomForestClassifier(**best_params, class_weight='balanced', random_state=42)
# best_rf = RandomForestClassifier(**best_params, random_state=42)
best_rf = RandomForestClassifier(
    **study.best_trial.params,
    class_weight='balanced',
    random_state=42
)
best_rf.fit(X_train_resampled, y_train_resampled)

# 테스트셋 평가
y_pred = best_rf.predict(X_scaled_test)
print("Classification Report (F1 기반 튜닝 + balanced):")
print(classification_report(y_test, y_pred))
# Out:
# [I 2025-03-31 18:41:00,880] A new study created in memory with name: no-name-c2b96015-cb28-47ab-9ba5-5e9e7188c8d5
# [I 2025-03-31 18:41:01,436] Trial 0 finished with value: 0.507962213225371 and parameters: {'n_estimators': 73, 'max_depth': 7, 'min_samples_split': 11, 'min_samples_leaf': 13, 'max_leaf_nodes': 40, 'max_features': 'sqrt', 'max_samples': 0.6593472622246394}. Best is trial 0 with value: 0.507962213225371.
# [I 2025-03-31 18:41:02,343] Trial 1 finished with value: 0.5549932523616734 and parameters: {'n_estimators': 135, 'max_depth': 6, 'min_samples_split': 36, 'min_samples_leaf': 5, 'max_leaf_nodes': 24, 'max_features': 'log2', 'max_samples': 0.8994466121667325}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:02,937] Trial 2 finished with value: 0.4791497975708502 and parameters: {'n_estimators': 90, 'max_depth': 7, 'min_samples_split': 33, 'min_samples_leaf': 27, 'max_leaf_nodes': 23, 'max_features': 'log2', 'max_samples': 0.7300467385684007}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:03,526] Trial 3 finished with value: 0.4925775978407557 and parameters: {'n_estimators': 90, 'max_depth': 2, 'min_samples_split': 29, 'min_samples_leaf': 20, 'max_leaf_nodes': 24, 'max_features': 'sqrt', 'max_samples': 0.6943227428421783}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:03,994] Trial 4 finished with value: 0.5214574898785423 and parameters: {'n_estimators': 59, 'max_depth': 2, 'min_samples_split': 23, 'min_samples_leaf': 7, 'max_leaf_nodes': 44, 'max_features': 'log2', 'max_samples': 0.8397765551466458}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:04,681] Trial 5 finished with value: 0.49730094466936575 and parameters: {'n_estimators': 106, 'max_depth': 6, 'min_samples_split': 40, 'min_samples_leaf': 21, 'max_leaf_nodes': 27, 'max_features': 'log2', 'max_samples': 0.7075878632678009}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:05,395] Trial 6 finished with value: 0.5238866396761134 and parameters: {'n_estimators': 111, 'max_depth': 2, 'min_samples_split': 36, 'min_samples_leaf': 8, 'max_leaf_nodes': 40, 'max_features': 'log2', 'max_samples': 0.5028565215633725}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:06,235] Trial 7 finished with value: 0.5367071524966261 and parameters: {'n_estimators': 144, 'max_depth': 3, 'min_samples_split': 17, 'min_samples_leaf': 7, 'max_leaf_nodes': 43, 'max_features': 'sqrt', 'max_samples': 0.8384574072081417}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:06,876] Trial 8 finished with value: 0.4973684210526315 and parameters: {'n_estimators': 93, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 19, 'max_leaf_nodes': 23, 'max_features': 'log2', 'max_samples': 0.5177077451228045}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:07,528] Trial 9 finished with value: 0.49743589743589745 and parameters: {'n_estimators': 102, 'max_depth': 7, 'min_samples_split': 20, 'min_samples_leaf': 24, 'max_leaf_nodes': 41, 'max_features': 'log2', 'max_samples': 0.613925717932059}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:08,452] Trial 10 finished with value: 0.5263832658569501 and parameters: {'n_estimators': 149, 'max_depth': 5, 'min_samples_split': 27, 'min_samples_leaf': 13, 'max_leaf_nodes': 11, 'max_features': 'sqrt', 'max_samples': 0.8969507614860277}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:09,367] Trial 11 finished with value: 0.5473684210526315 and parameters: {'n_estimators': 146, 'max_depth': 4, 'min_samples_split': 17, 'min_samples_leaf': 5, 'max_leaf_nodes': 50, 'max_features': 'sqrt', 'max_samples': 0.8119374106465643}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:10,204] Trial 12 finished with value: 0.5205802968960863 and parameters: {'n_estimators': 132, 'max_depth': 4, 'min_samples_split': 16, 'min_samples_leaf': 13, 'max_leaf_nodes': 50, 'max_features': 'sqrt', 'max_samples': 0.7935417823722148}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:11,050] Trial 13 finished with value: 0.5444669365721998 and parameters: {'n_estimators': 128, 'max_depth': 5, 'min_samples_split': 31, 'min_samples_leaf': 5, 'max_leaf_nodes': 33, 'max_features': 'sqrt', 'max_samples': 0.8958116196488314}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:11,865] Trial 14 finished with value: 0.5443994601889338 and parameters: {'n_estimators': 128, 'max_depth': 4, 'min_samples_split': 24, 'min_samples_leaf': 11, 'max_leaf_nodes': 16, 'max_features': 'log2', 'max_samples': 0.7864365832811415}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:12,648] Trial 15 finished with value: 0.5206477732793523 and parameters: {'n_estimators': 119, 'max_depth': 6, 'min_samples_split': 40, 'min_samples_leaf': 16, 'max_leaf_nodes': 34, 'max_features': 'sqrt', 'max_samples': 0.8357228808922316}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:13,640] Trial 16 finished with value: 0.5286774628879891 and parameters: {'n_estimators': 141, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 9, 'max_leaf_nodes': 16, 'max_features': 'sqrt', 'max_samples': 0.8031129305639628}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:14,531] Trial 17 finished with value: 0.5232793522267206 and parameters: {'n_estimators': 139, 'max_depth': 3, 'min_samples_split': 35, 'min_samples_leaf': 5, 'max_leaf_nodes': 49, 'max_features': 'log2', 'max_samples': 0.7509938534408409}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:15,383] Trial 18 finished with value: 0.5338731443994602 and parameters: {'n_estimators': 118, 'max_depth': 5, 'min_samples_split': 21, 'min_samples_leaf': 16, 'max_leaf_nodes': 31, 'max_features': 'log2', 'max_samples': 0.8651017664018866}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:16,214] Trial 19 finished with value: 0.4842780026990553 and parameters: {'n_estimators': 135, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 29, 'max_leaf_nodes': 36, 'max_features': 'sqrt', 'max_samples': 0.7689744748709678}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:16,961] Trial 20 finished with value: 0.5233468286099865 and parameters: {'n_estimators': 120, 'max_depth': 3, 'min_samples_split': 27, 'min_samples_leaf': 10, 'max_leaf_nodes': 17, 'max_features': 'sqrt', 'max_samples': 0.6078091952196005}. Best is trial 1 with value: 0.5549932523616734.
# [I 2025-03-31 18:41:17,758] Trial 21 finished with value: 0.5600539811066126 and parameters: {'n_estimators': 127, 'max_depth': 5, 'min_samples_split': 31, 'min_samples_leaf': 5, 'max_leaf_nodes': 30, 'max_features': 'sqrt', 'max_samples': 0.8906089265901739}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:18,681] Trial 22 finished with value: 0.5597165991902834 and parameters: {'n_estimators': 148, 'max_depth': 5, 'min_samples_split': 37, 'min_samples_leaf': 5, 'max_leaf_nodes': 28, 'max_features': 'sqrt', 'max_samples': 0.8713787383992782}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:19,464] Trial 23 finished with value: 0.5391363022941971 and parameters: {'n_estimators': 126, 'max_depth': 6, 'min_samples_split': 37, 'min_samples_leaf': 7, 'max_leaf_nodes': 28, 'max_features': 'sqrt', 'max_samples': 0.8660180487749694}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:20,418] Trial 24 finished with value: 0.5394736842105263 and parameters: {'n_estimators': 150, 'max_depth': 5, 'min_samples_split': 33, 'min_samples_leaf': 11, 'max_leaf_nodes': 20, 'max_features': 'sqrt', 'max_samples': 0.8766061716698409}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:21,290] Trial 25 finished with value: 0.5158569500674763 and parameters: {'n_estimators': 136, 'max_depth': 6, 'min_samples_split': 38, 'min_samples_leaf': 5, 'max_leaf_nodes': 28, 'max_features': 'sqrt', 'max_samples': 0.8532944891010762}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:22,055] Trial 26 finished with value: 0.52361673414305 and parameters: {'n_estimators': 113, 'max_depth': 5, 'min_samples_split': 33, 'min_samples_leaf': 9, 'max_leaf_nodes': 31, 'max_features': 'log2', 'max_samples': 0.8236073055706347}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:22,840] Trial 27 finished with value: 0.5441970310391363 and parameters: {'n_estimators': 124, 'max_depth': 6, 'min_samples_split': 31, 'min_samples_leaf': 15, 'max_leaf_nodes': 36, 'max_features': 'sqrt', 'max_samples': 0.8986143650441124}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:23,729] Trial 28 finished with value: 0.5367071524966263 and parameters: {'n_estimators': 139, 'max_depth': 5, 'min_samples_split': 35, 'min_samples_leaf': 7, 'max_leaf_nodes': 26, 'max_features': 'log2', 'max_samples': 0.8672986393556418}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:24,186] Trial 29 finished with value: 0.5311740890688259 and parameters: {'n_estimators': 53, 'max_depth': 7, 'min_samples_split': 38, 'min_samples_leaf': 12, 'max_leaf_nodes': 21, 'max_features': 'sqrt', 'max_samples': 0.642377035374869}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:24,720] Trial 30 finished with value: 0.5413630229419703 and parameters: {'n_estimators': 74, 'max_depth': 6, 'min_samples_split': 30, 'min_samples_leaf': 9, 'max_leaf_nodes': 30, 'max_features': 'sqrt', 'max_samples': 0.77444657945497}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:25,619] Trial 31 finished with value: 0.5597840755735491 and parameters: {'n_estimators': 145, 'max_depth': 4, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_leaf_nodes': 37, 'max_features': 'sqrt', 'max_samples': 0.8153936358498899}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:26,512] Trial 32 finished with value: 0.5469635627530364 and parameters: {'n_estimators': 132, 'max_depth': 4, 'min_samples_split': 34, 'min_samples_leaf': 6, 'max_leaf_nodes': 36, 'max_features': 'sqrt', 'max_samples': 0.873180311917282}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:27,429] Trial 33 finished with value: 0.5365721997300945 and parameters: {'n_estimators': 144, 'max_depth': 5, 'min_samples_split': 28, 'min_samples_leaf': 8, 'max_leaf_nodes': 25, 'max_features': 'sqrt', 'max_samples': 0.8195836839222315}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:28,362] Trial 34 finished with value: 0.5393387314439947 and parameters: {'n_estimators': 150, 'max_depth': 4, 'min_samples_split': 32, 'min_samples_leaf': 6, 'max_leaf_nodes': 38, 'max_features': 'sqrt', 'max_samples': 0.849855081405792}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:28,899] Trial 35 finished with value: 0.5261133603238867 and parameters: {'n_estimators': 77, 'max_depth': 5, 'min_samples_split': 12, 'min_samples_leaf': 23, 'max_leaf_nodes': 33, 'max_features': 'sqrt', 'max_samples': 0.8903705148198406}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:29,760] Trial 36 finished with value: 0.5155870445344128 and parameters: {'n_estimators': 133, 'max_depth': 3, 'min_samples_split': 38, 'min_samples_leaf': 8, 'max_leaf_nodes': 19, 'max_features': 'log2', 'max_samples': 0.7271110865618529}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:30,637] Trial 37 finished with value: 0.533940620782726 and parameters: {'n_estimators': 142, 'max_depth': 4, 'min_samples_split': 25, 'min_samples_leaf': 6, 'max_leaf_nodes': 29, 'max_features': 'log2', 'max_samples': 0.6865541994020293}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:31,263] Trial 38 finished with value: 0.5520242914979757 and parameters: {'n_estimators': 93, 'max_depth': 6, 'min_samples_split': 40, 'min_samples_leaf': 11, 'max_leaf_nodes': 23, 'max_features': 'sqrt', 'max_samples': 0.8417659071287469}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:31,988] Trial 39 finished with value: 0.5521592442645072 and parameters: {'n_estimators': 107, 'max_depth': 7, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_leaf_nodes': 25, 'max_features': 'log2', 'max_samples': 0.8789642029673653}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:32,524] Trial 40 finished with value: 0.5128879892037788 and parameters: {'n_estimators': 66, 'max_depth': 5, 'min_samples_split': 36, 'min_samples_leaf': 14, 'max_leaf_nodes': 43, 'max_features': 'sqrt', 'max_samples': 0.5580020360580105}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:33,132] Trial 41 finished with value: 0.5418353576248313 and parameters: {'n_estimators': 83, 'max_depth': 7, 'min_samples_split': 21, 'min_samples_leaf': 7, 'max_leaf_nodes': 25, 'max_features': 'log2', 'max_samples': 0.882959499919175}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:33,841] Trial 42 finished with value: 0.5340755735492577 and parameters: {'n_estimators': 103, 'max_depth': 7, 'min_samples_split': 22, 'min_samples_leaf': 5, 'max_leaf_nodes': 27, 'max_features': 'log2', 'max_samples': 0.8588868214413296}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:34,570] Trial 43 finished with value: 0.5522941970310391 and parameters: {'n_estimators': 109, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_leaf_nodes': 22, 'max_features': 'log2', 'max_samples': 0.8321892094376256}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:35,298] Trial 44 finished with value: 0.5571524966261808 and parameters: {'n_estimators': 111, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_leaf_nodes': 22, 'max_features': 'log2', 'max_samples': 0.8320014319880074}. Best is trial 21 with value: 0.5600539811066126.
# [I 2025-03-31 18:41:36,035] Trial 45 finished with value: 0.5730094466936573 and parameters: {'n_estimators': 114, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_leaf_nodes': 40, 'max_features': 'log2', 'max_samples': 0.8101007011162639}. Best is trial 45 with value: 0.5730094466936573.
# [I 2025-03-31 18:41:36,699] Trial 46 finished with value: 0.4922402159244264 and parameters: {'n_estimators': 98, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_leaf_nodes': 47, 'max_features': 'log2', 'max_samples': 0.759722478988028}. Best is trial 45 with value: 0.5730094466936573.
# [I 2025-03-31 18:41:37,446] Trial 47 finished with value: 0.5572199730094467 and parameters: {'n_estimators': 114, 'max_depth': 5, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_leaf_nodes': 39, 'max_features': 'log2', 'max_samples': 0.7985317792352999}. Best is trial 45 with value: 0.5730094466936573.
# [I 2025-03-31 18:41:38,200] Trial 48 finished with value: 0.5076248313090418 and parameters: {'n_estimators': 117, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 26, 'max_leaf_nodes': 40, 'max_features': 'sqrt', 'max_samples': 0.8018659012309058}. Best is trial 45 with value: 0.5730094466936573.
# [I 2025-03-31 18:41:38,984] Trial 49 finished with value: 0.5492577597840756 and parameters: {'n_estimators': 124, 'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_leaf_nodes': 45, 'max_features': 'log2', 'max_samples': 0.738816708678941}. Best is trial 45 with value: 0.5730094466936573.
# [I 2025-03-31 18:41:39,637] Trial 50 finished with value: 0.5184210526315789 and parameters: {'n_estimators': 99, 'max_depth': 5, 'min_samples_split': 18, 'min_samples_leaf': 19, 'max_leaf_nodes': 40, 'max_features': 'sqrt', 'max_samples': 0.7878758093126773}. Best is trial 45 with value: 0.5730094466936573.
# [I 2025-03-31 18:41:40,345] Trial 51 finished with value: 0.5755735492577598 and parameters: {'n_estimators': 110, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_leaf_nodes': 38, 'max_features': 'log2', 'max_samples': 0.8112905451875068}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:41,070] Trial 52 finished with value: 0.5701079622132253 and parameters: {'n_estimators': 113, 'max_depth': 5, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_leaf_nodes': 38, 'max_features': 'log2', 'max_samples': 0.8135614775613088}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:41,841] Trial 53 finished with value: 0.5392712550607287 and parameters: {'n_estimators': 122, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_leaf_nodes': 37, 'max_features': 'log2', 'max_samples': 0.8132996518492772}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:42,531] Trial 54 finished with value: 0.5467611336032389 and parameters: {'n_estimators': 105, 'max_depth': 3, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_leaf_nodes': 33, 'max_features': 'log2', 'max_samples': 0.7755190283141532}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:43,332] Trial 55 finished with value: 0.523549257759784 and parameters: {'n_estimators': 129, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 10, 'max_leaf_nodes': 42, 'max_features': 'log2', 'max_samples': 0.8175513345053534}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:44,210] Trial 56 finished with value: 0.5520242914979757 and parameters: {'n_estimators': 146, 'max_depth': 5, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_leaf_nodes': 34, 'max_features': 'log2', 'max_samples': 0.7221223132910185}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:44,957] Trial 57 finished with value: 0.5625506072874493 and parameters: {'n_estimators': 116, 'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_leaf_nodes': 46, 'max_features': 'sqrt', 'max_samples': 0.8467495382505321}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:45,709] Trial 58 finished with value: 0.5520242914979757 and parameters: {'n_estimators': 116, 'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_leaf_nodes': 46, 'max_features': 'log2', 'max_samples': 0.7468815949701041}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:46,422] Trial 59 finished with value: 0.5524291497975709 and parameters: {'n_estimators': 110, 'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_leaf_nodes': 48, 'max_features': 'sqrt', 'max_samples': 0.8479676523525401}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:47,062] Trial 60 finished with value: 0.5417004048582996 and parameters: {'n_estimators': 94, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 12, 'max_leaf_nodes': 44, 'max_features': 'sqrt', 'max_samples': 0.7885771519422428}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:47,832] Trial 61 finished with value: 0.5470310391363024 and parameters: {'n_estimators': 120, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 5, 'max_leaf_nodes': 42, 'max_features': 'sqrt', 'max_samples': 0.8326432818884844}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:48,565] Trial 62 finished with value: 0.5573549257759784 and parameters: {'n_estimators': 115, 'max_depth': 5, 'min_samples_split': 11, 'min_samples_leaf': 8, 'max_leaf_nodes': 38, 'max_features': 'sqrt', 'max_samples': 0.8550542107945927}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:49,415] Trial 63 finished with value: 0.5421052631578946 and parameters: {'n_estimators': 137, 'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_leaf_nodes': 32, 'max_features': 'sqrt', 'max_samples': 0.8095410316223829}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:50,212] Trial 64 finished with value: 0.5626855600539812 and parameters: {'n_estimators': 128, 'max_depth': 4, 'min_samples_split': 17, 'min_samples_leaf': 7, 'max_leaf_nodes': 35, 'max_features': 'sqrt', 'max_samples': 0.8856994034133573}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:51,016] Trial 65 finished with value: 0.5520917678812416 and parameters: {'n_estimators': 129, 'max_depth': 4, 'min_samples_split': 17, 'min_samples_leaf': 7, 'max_leaf_nodes': 35, 'max_features': 'sqrt', 'max_samples': 0.8888610328211254}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:51,772] Trial 66 finished with value: 0.5624831309041836 and parameters: {'n_estimators': 122, 'max_depth': 4, 'min_samples_split': 19, 'min_samples_leaf': 9, 'max_leaf_nodes': 38, 'max_features': 'sqrt', 'max_samples': 0.8253046841494337}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:52,548] Trial 67 finished with value: 0.5131578947368421 and parameters: {'n_estimators': 124, 'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_leaf_nodes': 42, 'max_features': 'log2', 'max_samples': 0.8430459461476421}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:53,316] Trial 68 finished with value: 0.5602564102564103 and parameters: {'n_estimators': 121, 'max_depth': 4, 'min_samples_split': 23, 'min_samples_leaf': 9, 'max_leaf_nodes': 39, 'max_features': 'sqrt', 'max_samples': 0.862570227774967}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:54,043] Trial 69 finished with value: 0.5444669365721998 and parameters: {'n_estimators': 113, 'max_depth': 4, 'min_samples_split': 18, 'min_samples_leaf': 12, 'max_leaf_nodes': 39, 'max_features': 'sqrt', 'max_samples': 0.8243565861093695}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:54,819] Trial 70 finished with value: 0.5549932523616734 and parameters: {'n_estimators': 122, 'max_depth': 4, 'min_samples_split': 24, 'min_samples_leaf': 9, 'max_leaf_nodes': 41, 'max_features': 'sqrt', 'max_samples': 0.8666559874103982}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:55,629] Trial 71 finished with value: 0.5497975708502024 and parameters: {'n_estimators': 119, 'max_depth': 4, 'min_samples_split': 25, 'min_samples_leaf': 7, 'max_leaf_nodes': 38, 'max_features': 'sqrt', 'max_samples': 0.8974114996553727}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:56,438] Trial 72 finished with value: 0.5417678812415654 and parameters: {'n_estimators': 127, 'max_depth': 3, 'min_samples_split': 23, 'min_samples_leaf': 9, 'max_leaf_nodes': 35, 'max_features': 'sqrt', 'max_samples': 0.8607645402723546}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:57,132] Trial 73 finished with value: 0.5522941970310391 and parameters: {'n_estimators': 107, 'max_depth': 4, 'min_samples_split': 19, 'min_samples_leaf': 8, 'max_leaf_nodes': 40, 'max_features': 'sqrt', 'max_samples': 0.8792517783564681}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:57,943] Trial 74 finished with value: 0.5287449392712551 and parameters: {'n_estimators': 131, 'max_depth': 4, 'min_samples_split': 16, 'min_samples_leaf': 11, 'max_leaf_nodes': 37, 'max_features': 'sqrt', 'max_samples': 0.8451617777594809}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:58,708] Trial 75 finished with value: 0.5727395411605938 and parameters: {'n_estimators': 122, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 10, 'max_leaf_nodes': 35, 'max_features': 'sqrt', 'max_samples': 0.77778846064542}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:41:59,468] Trial 76 finished with value: 0.5727395411605938 and parameters: {'n_estimators': 122, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_leaf_nodes': 35, 'max_features': 'sqrt', 'max_samples': 0.778241707194294}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:00,184] Trial 77 finished with value: 0.5518218623481781 and parameters: {'n_estimators': 112, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 13, 'max_leaf_nodes': 35, 'max_features': 'log2', 'max_samples': 0.7780318559008282}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:00,927] Trial 78 finished with value: 0.5290823211875844 and parameters: {'n_estimators': 116, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 11, 'max_leaf_nodes': 32, 'max_features': 'sqrt', 'max_samples': 0.7641681502267517}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:01,611] Trial 79 finished with value: 0.5650472334682861 and parameters: {'n_estimators': 103, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 10, 'max_leaf_nodes': 12, 'max_features': 'log2', 'max_samples': 0.8046251462590372}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:02,307] Trial 80 finished with value: 0.531578947368421 and parameters: {'n_estimators': 105, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 10, 'max_leaf_nodes': 34, 'max_features': 'log2', 'max_samples': 0.7970340173864332}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:02,968] Trial 81 finished with value: 0.5182860998650473 and parameters: {'n_estimators': 101, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 17, 'max_leaf_nodes': 10, 'max_features': 'log2', 'max_samples': 0.8256585761768623}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:03,659] Trial 82 finished with value: 0.5524291497975709 and parameters: {'n_estimators': 108, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_leaf_nodes': 36, 'max_features': 'log2', 'max_samples': 0.7827959380788929}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:04,303] Trial 83 finished with value: 0.5262483130904184 and parameters: {'n_estimators': 96, 'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_leaf_nodes': 37, 'max_features': 'log2', 'max_samples': 0.7969993921145349}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:05,102] Trial 84 finished with value: 0.5233468286099865 and parameters: {'n_estimators': 125, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_leaf_nodes': 12, 'max_features': 'log2', 'max_samples': 0.7559622137482367}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:05,846] Trial 85 finished with value: 0.5100539811066127 and parameters: {'n_estimators': 118, 'max_depth': 2, 'min_samples_split': 13, 'min_samples_leaf': 14, 'max_leaf_nodes': 44, 'max_features': 'sqrt', 'max_samples': 0.80759237495883}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:06,521] Trial 86 finished with value: 0.4923751686909581 and parameters: {'n_estimators': 103, 'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 21, 'max_leaf_nodes': 41, 'max_features': 'log2', 'max_samples': 0.6868889977370921}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:07,234] Trial 87 finished with value: 0.5595141700404859 and parameters: {'n_estimators': 111, 'max_depth': 7, 'min_samples_split': 11, 'min_samples_leaf': 11, 'max_leaf_nodes': 31, 'max_features': 'sqrt', 'max_samples': 0.7689420693098333}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:08,007] Trial 88 finished with value: 0.5315114709851552 and parameters: {'n_estimators': 122, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_leaf_nodes': 38, 'max_features': 'log2', 'max_samples': 0.8057993730157457}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:08,616] Trial 89 finished with value: 0.5286774628879891 and parameters: {'n_estimators': 89, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_leaf_nodes': 35, 'max_features': 'sqrt', 'max_samples': 0.712654144778532}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:09,351] Trial 90 finished with value: 0.5625506072874493 and parameters: {'n_estimators': 114, 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_leaf_nodes': 50, 'max_features': 'log2', 'max_samples': 0.8364391048410242}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:10,088] Trial 91 finished with value: 0.5495951417004049 and parameters: {'n_estimators': 115, 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_leaf_nodes': 50, 'max_features': 'log2', 'max_samples': 0.8238220666908188}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:10,810] Trial 92 finished with value: 0.5677462887989203 and parameters: {'n_estimators': 113, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_leaf_nodes': 46, 'max_features': 'log2', 'max_samples': 0.8340346884895113}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:11,524] Trial 93 finished with value: 0.560323886639676 and parameters: {'n_estimators': 110, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 9, 'max_leaf_nodes': 48, 'max_features': 'log2', 'max_samples': 0.8374295106132846}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:12,249] Trial 94 finished with value: 0.49757085020242914 and parameters: {'n_estimators': 113, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 30, 'max_leaf_nodes': 47, 'max_features': 'log2', 'max_samples': 0.7894422997423073}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:12,950] Trial 95 finished with value: 0.5525641025641025 and parameters: {'n_estimators': 106, 'max_depth': 7, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_leaf_nodes': 46, 'max_features': 'log2', 'max_samples': 0.8514951420670736}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:13,686] Trial 96 finished with value: 0.5468960863697705 and parameters: {'n_estimators': 117, 'max_depth': 7, 'min_samples_split': 11, 'min_samples_leaf': 10, 'max_leaf_nodes': 49, 'max_features': 'log2', 'max_samples': 0.8177199778611209}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:14,441] Trial 97 finished with value: 0.5493252361673414 and parameters: {'n_estimators': 119, 'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_leaf_nodes': 45, 'max_features': 'log2', 'max_samples': 0.6644157445944022}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:15,104] Trial 98 finished with value: 0.5675438596491228 and parameters: {'n_estimators': 103, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_leaf_nodes': 49, 'max_features': 'log2', 'max_samples': 0.7416057495104064}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:15,817] Trial 99 finished with value: 0.5492577597840755 and parameters: {'n_estimators': 104, 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_leaf_nodes': 43, 'max_features': 'log2', 'max_samples': 0.7401522390402598}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:16,466] Trial 100 finished with value: 0.5624831309041836 and parameters: {'n_estimators': 100, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 6, 'max_leaf_nodes': 49, 'max_features': 'log2', 'max_samples': 0.7692619769065407}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:17,167] Trial 101 finished with value: 0.5570175438596492 and parameters: {'n_estimators': 108, 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_leaf_nodes': 48, 'max_features': 'log2', 'max_samples': 0.7825263607650496}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:17,887] Trial 102 finished with value: 0.557557354925776 and parameters: {'n_estimators': 113, 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_leaf_nodes': 50, 'max_features': 'log2', 'max_samples': 0.8103578866589419}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:18,603] Trial 103 finished with value: 0.5572199730094467 and parameters: {'n_estimators': 110, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_leaf_nodes': 13, 'max_features': 'log2', 'max_samples': 0.8333497301407454}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:19,343] Trial 104 finished with value: 0.5392037786774628 and parameters: {'n_estimators': 102, 'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 9, 'max_leaf_nodes': 47, 'max_features': 'log2', 'max_samples': 0.7953000593193016}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:19,988] Trial 105 finished with value: 0.549460188933873 and parameters: {'n_estimators': 97, 'max_depth': 7, 'min_samples_split': 18, 'min_samples_leaf': 7, 'max_leaf_nodes': 46, 'max_features': 'log2', 'max_samples': 0.8021329833971761}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:20,702] Trial 106 finished with value: 0.5443994601889338 and parameters: {'n_estimators': 116, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 6, 'max_leaf_nodes': 45, 'max_features': 'log2', 'max_samples': 0.7460732342931929}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:21,408] Trial 107 finished with value: 0.5414304993252361 and parameters: {'n_estimators': 114, 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 10, 'max_leaf_nodes': 49, 'max_features': 'log2', 'max_samples': 0.5422032715797657}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:22,191] Trial 108 finished with value: 0.5336707152496627 and parameters: {'n_estimators': 126, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_leaf_nodes': 33, 'max_features': 'log2', 'max_samples': 0.7576258456581305}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:23,020] Trial 109 finished with value: 0.5574224021592442 and parameters: {'n_estimators': 130, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 5, 'max_leaf_nodes': 36, 'max_features': 'log2', 'max_samples': 0.8377391786963482}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:23,776] Trial 110 finished with value: 0.5390013495276653 and parameters: {'n_estimators': 120, 'max_depth': 7, 'min_samples_split': 16, 'min_samples_leaf': 8, 'max_leaf_nodes': 40, 'max_features': 'log2', 'max_samples': 0.8150999623091165}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:24,543] Trial 111 finished with value: 0.5390688259109313 and parameters: {'n_estimators': 122, 'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 9, 'max_leaf_nodes': 39, 'max_features': 'sqrt', 'max_samples': 0.8203640324748721}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:25,261] Trial 112 finished with value: 0.5649797570850202 and parameters: {'n_estimators': 109, 'max_depth': 6, 'min_samples_split': 21, 'min_samples_leaf': 8, 'max_leaf_nodes': 34, 'max_features': 'sqrt', 'max_samples': 0.8299002695057124}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:25,962] Trial 113 finished with value: 0.5494601889338732 and parameters: {'n_estimators': 109, 'max_depth': 6, 'min_samples_split': 21, 'min_samples_leaf': 11, 'max_leaf_nodes': 34, 'max_features': 'sqrt', 'max_samples': 0.8419841636488093}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:26,646] Trial 114 finished with value: 0.5439271255060729 and parameters: {'n_estimators': 105, 'max_depth': 6, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_leaf_nodes': 29, 'max_features': 'sqrt', 'max_samples': 0.7904883439125772}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:27,480] Trial 115 finished with value: 0.5520242914979756 and parameters: {'n_estimators': 134, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_leaf_nodes': 32, 'max_features': 'sqrt', 'max_samples': 0.8273396423893823}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:28,203] Trial 116 finished with value: 0.5572199730094467 and parameters: {'n_estimators': 112, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 8, 'max_leaf_nodes': 18, 'max_features': 'sqrt', 'max_samples': 0.8536164164700185}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:28,900] Trial 117 finished with value: 0.5465587044534412 and parameters: {'n_estimators': 107, 'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_leaf_nodes': 37, 'max_features': 'log2', 'max_samples': 0.7776830823943601}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:29,647] Trial 118 finished with value: 0.5624156545209177 and parameters: {'n_estimators': 118, 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 10, 'max_leaf_nodes': 36, 'max_features': 'sqrt', 'max_samples': 0.8045418052990607}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:30,429] Trial 119 finished with value: 0.5653171390013496 and parameters: {'n_estimators': 124, 'max_depth': 6, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_leaf_nodes': 48, 'max_features': 'log2', 'max_samples': 0.8136477829362819}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:31,276] Trial 120 finished with value: 0.5549257759784075 and parameters: {'n_estimators': 127, 'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 6, 'max_leaf_nodes': 35, 'max_features': 'sqrt', 'max_samples': 0.8728504202130433}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:32,071] Trial 121 finished with value: 0.534008097165992 and parameters: {'n_estimators': 124, 'max_depth': 6, 'min_samples_split': 20, 'min_samples_leaf': 5, 'max_leaf_nodes': 47, 'max_features': 'log2', 'max_samples': 0.8302507018323665}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:32,845] Trial 122 finished with value: 0.5597840755735493 and parameters: {'n_estimators': 115, 'max_depth': 6, 'min_samples_split': 22, 'min_samples_leaf': 8, 'max_leaf_nodes': 48, 'max_features': 'log2', 'max_samples': 0.8094411096417305}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:33,566] Trial 123 finished with value: 0.5315114709851552 and parameters: {'n_estimators': 111, 'max_depth': 6, 'min_samples_split': 21, 'min_samples_leaf': 6, 'max_leaf_nodes': 50, 'max_features': 'log2', 'max_samples': 0.8186576660743751}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:34,345] Trial 124 finished with value: 0.5675438596491228 and parameters: {'n_estimators': 118, 'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 7, 'max_leaf_nodes': 34, 'max_features': 'log2', 'max_samples': 0.7969578424878395}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:35,160] Trial 125 finished with value: 0.5624831309041836 and parameters: {'n_estimators': 123, 'max_depth': 6, 'min_samples_split': 20, 'min_samples_leaf': 7, 'max_leaf_nodes': 34, 'max_features': 'log2', 'max_samples': 0.7942602613349283}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:35,955] Trial 126 finished with value: 0.5548582995951417 and parameters: {'n_estimators': 118, 'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 7, 'max_leaf_nodes': 36, 'max_features': 'log2', 'max_samples': 0.7830107873259649}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:36,736] Trial 127 finished with value: 0.5497300944669365 and parameters: {'n_estimators': 121, 'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 5, 'max_leaf_nodes': 33, 'max_features': 'sqrt', 'max_samples': 0.8018774355811327}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:37,533] Trial 128 finished with value: 0.5647773279352227 and parameters: {'n_estimators': 125, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 6, 'max_leaf_nodes': 31, 'max_features': 'log2', 'max_samples': 0.7679468206744179}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:38,339] Trial 129 finished with value: 0.5597840755735494 and parameters: {'n_estimators': 132, 'max_depth': 6, 'min_samples_split': 22, 'min_samples_leaf': 6, 'max_leaf_nodes': 31, 'max_features': 'log2', 'max_samples': 0.7691137430882515}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:39,167] Trial 130 finished with value: 0.5678137651821862 and parameters: {'n_estimators': 128, 'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 5, 'max_leaf_nodes': 32, 'max_features': 'log2', 'max_samples': 0.7353690457423834}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:39,961] Trial 131 finished with value: 0.5315114709851552 and parameters: {'n_estimators': 126, 'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 5, 'max_leaf_nodes': 32, 'max_features': 'log2', 'max_samples': 0.7365764889285707}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:40,769] Trial 132 finished with value: 0.5600539811066125 and parameters: {'n_estimators': 130, 'max_depth': 5, 'min_samples_split': 16, 'min_samples_leaf': 6, 'max_leaf_nodes': 29, 'max_features': 'log2', 'max_samples': 0.7228555556239096}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:41,529] Trial 133 finished with value: 0.5419028340080971 and parameters: {'n_estimators': 120, 'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 5, 'max_leaf_nodes': 30, 'max_features': 'log2', 'max_samples': 0.7544415987176951}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:42,318] Trial 134 finished with value: 0.5496626180836708 and parameters: {'n_estimators': 129, 'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 7, 'max_leaf_nodes': 34, 'max_features': 'log2', 'max_samples': 0.7089819216108125}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:43,167] Trial 135 finished with value: 0.5547908232118759 and parameters: {'n_estimators': 136, 'max_depth': 5, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_leaf_nodes': 31, 'max_features': 'log2', 'max_samples': 0.7658459627782738}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:43,958] Trial 136 finished with value: 0.5442645074224022 and parameters: {'n_estimators': 127, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 5, 'max_leaf_nodes': 33, 'max_features': 'log2', 'max_samples': 0.7830522582812194}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:44,741] Trial 137 finished with value: 0.5625506072874493 and parameters: {'n_estimators': 124, 'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 6, 'max_leaf_nodes': 15, 'max_features': 'log2', 'max_samples': 0.7759160751954628}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:45,468] Trial 138 finished with value: 0.5544534412955466 and parameters: {'n_estimators': 102, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 7, 'max_leaf_nodes': 35, 'max_features': 'log2', 'max_samples': 0.7333574256298966}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:46,246] Trial 139 finished with value: 0.5545209176788124 and parameters: {'n_estimators': 125, 'max_depth': 5, 'min_samples_split': 26, 'min_samples_leaf': 5, 'max_leaf_nodes': 32, 'max_features': 'log2', 'max_samples': 0.7462577216737281}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:46,962] Trial 140 finished with value: 0.5441295546558704 and parameters: {'n_estimators': 108, 'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_leaf_nodes': 30, 'max_features': 'log2', 'max_samples': 0.7615111511754524}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:47,722] Trial 141 finished with value: 0.5574224021592442 and parameters: {'n_estimators': 116, 'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 9, 'max_leaf_nodes': 44, 'max_features': 'sqrt', 'max_samples': 0.8115262348950261}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:48,490] Trial 142 finished with value: 0.5263157894736843 and parameters: {'n_estimators': 118, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 8, 'max_leaf_nodes': 34, 'max_features': 'log2', 'max_samples': 0.7966462119208593}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:49,274] Trial 143 finished with value: 0.5363697705802969 and parameters: {'n_estimators': 121, 'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 10, 'max_leaf_nodes': 41, 'max_features': 'sqrt', 'max_samples': 0.7872351443501421}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:49,992] Trial 144 finished with value: 0.5470310391363024 and parameters: {'n_estimators': 112, 'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 6, 'max_leaf_nodes': 37, 'max_features': 'log2', 'max_samples': 0.8149332105658645}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:50,700] Trial 145 finished with value: 0.53110661268556 and parameters: {'n_estimators': 106, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 12, 'max_leaf_nodes': 33, 'max_features': 'log2', 'max_samples': 0.7171896149494033}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:51,382] Trial 146 finished with value: 0.5649122807017544 and parameters: {'n_estimators': 100, 'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 11, 'max_leaf_nodes': 35, 'max_features': 'sqrt', 'max_samples': 0.8063144404253848}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:52,002] Trial 147 finished with value: 0.5625506072874493 and parameters: {'n_estimators': 94, 'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 11, 'max_leaf_nodes': 38, 'max_features': 'sqrt', 'max_samples': 0.7733157635552622}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:52,664] Trial 148 finished with value: 0.5444669365721998 and parameters: {'n_estimators': 100, 'max_depth': 5, 'min_samples_split': 14, 'min_samples_leaf': 11, 'max_leaf_nodes': 35, 'max_features': 'log2', 'max_samples': 0.8017992764798655}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:53,281] Trial 149 finished with value: 0.49244264507422403 and parameters: {'n_estimators': 88, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 19, 'max_leaf_nodes': 36, 'max_features': 'log2', 'max_samples': 0.7929636663696101}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:53,761] Trial 150 finished with value: 0.5365047233468287 and parameters: {'n_estimators': 63, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_leaf_nodes': 27, 'max_features': 'sqrt', 'max_samples': 0.6117172778063487}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:54,438] Trial 151 finished with value: 0.5576923076923077 and parameters: {'n_estimators': 98, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 9, 'max_leaf_nodes': 35, 'max_features': 'sqrt', 'max_samples': 0.8215860376814905}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:55,130] Trial 152 finished with value: 0.5472334682860998 and parameters: {'n_estimators': 104, 'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 9, 'max_leaf_nodes': 46, 'max_features': 'sqrt', 'max_samples': 0.8281071890664693}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:55,857] Trial 153 finished with value: 0.547165991902834 and parameters: {'n_estimators': 110, 'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_leaf_nodes': 34, 'max_features': 'sqrt', 'max_samples': 0.8062271045191325}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:56,654] Trial 154 finished with value: 0.5547908232118759 and parameters: {'n_estimators': 128, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_leaf_nodes': 37, 'max_features': 'sqrt', 'max_samples': 0.8476285871275655}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:57,403] Trial 155 finished with value: 0.5026315789473684 and parameters: {'n_estimators': 114, 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 24, 'max_leaf_nodes': 32, 'max_features': 'sqrt', 'max_samples': 0.8108893162834669}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:58,213] Trial 156 finished with value: 0.5416329284750339 and parameters: {'n_estimators': 123, 'max_depth': 6, 'min_samples_split': 12, 'min_samples_leaf': 6, 'max_leaf_nodes': 39, 'max_features': 'log2', 'max_samples': 0.6984140859923075}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:58,951] Trial 157 finished with value: 0.5420377867746289 and parameters: {'n_estimators': 116, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 5, 'max_leaf_nodes': 49, 'max_features': 'sqrt', 'max_samples': 0.7887063481330463}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:42:59,718] Trial 158 finished with value: 0.5728070175438595 and parameters: {'n_estimators': 119, 'max_depth': 6, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_leaf_nodes': 33, 'max_features': 'log2', 'max_samples': 0.8390456646835025}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:00,505] Trial 159 finished with value: 0.5441970310391363 and parameters: {'n_estimators': 119, 'max_depth': 7, 'min_samples_split': 21, 'min_samples_leaf': 10, 'max_leaf_nodes': 34, 'max_features': 'log2', 'max_samples': 0.800740986071707}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:01,334] Trial 160 finished with value: 0.5417004048582996 and parameters: {'n_estimators': 125, 'max_depth': 6, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_leaf_nodes': 33, 'max_features': 'log2', 'max_samples': 0.8179776642870751}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:02,093] Trial 161 finished with value: 0.5496626180836708 and parameters: {'n_estimators': 120, 'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 9, 'max_leaf_nodes': 31, 'max_features': 'log2', 'max_samples': 0.8381767822989626}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:02,728] Trial 162 finished with value: 0.5653171390013496 and parameters: {'n_estimators': 96, 'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 10, 'max_leaf_nodes': 33, 'max_features': 'log2', 'max_samples': 0.8601118520254515}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:03,356] Trial 163 finished with value: 0.5341430499325235 and parameters: {'n_estimators': 96, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 12, 'max_leaf_nodes': 33, 'max_features': 'log2', 'max_samples': 0.862509172206453}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:03,986] Trial 164 finished with value: 0.5599865047233468 and parameters: {'n_estimators': 92, 'max_depth': 6, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_leaf_nodes': 35, 'max_features': 'log2', 'max_samples': 0.8849365725360251}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:04,650] Trial 165 finished with value: 0.5676788124156544 and parameters: {'n_estimators': 99, 'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 11, 'max_leaf_nodes': 36, 'max_features': 'log2', 'max_samples': 0.8344328466372566}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:05,306] Trial 166 finished with value: 0.5545209176788124 and parameters: {'n_estimators': 97, 'max_depth': 6, 'min_samples_split': 22, 'min_samples_leaf': 11, 'max_leaf_nodes': 36, 'max_features': 'log2', 'max_samples': 0.823576940862686}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:05,950] Trial 167 finished with value: 0.55472334682861 and parameters: {'n_estimators': 99, 'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 11, 'max_leaf_nodes': 36, 'max_features': 'log2', 'max_samples': 0.8307663848843078}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:06,603] Trial 168 finished with value: 0.5337381916329285 and parameters: {'n_estimators': 100, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 13, 'max_leaf_nodes': 37, 'max_features': 'log2', 'max_samples': 0.8459601727590071}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:07,297] Trial 169 finished with value: 0.5598515519568152 and parameters: {'n_estimators': 106, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 10, 'max_leaf_nodes': 32, 'max_features': 'log2', 'max_samples': 0.8564353269867451}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:07,980] Trial 170 finished with value: 0.5519568151147098 and parameters: {'n_estimators': 103, 'max_depth': 6, 'min_samples_split': 21, 'min_samples_leaf': 11, 'max_leaf_nodes': 38, 'max_features': 'log2', 'max_samples': 0.8384887320507929}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:08,623] Trial 171 finished with value: 0.5574898785425102 and parameters: {'n_estimators': 95, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 6, 'max_leaf_nodes': 34, 'max_features': 'log2', 'max_samples': 0.8127412326959486}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:09,265] Trial 172 finished with value: 0.5446693657219972 and parameters: {'n_estimators': 92, 'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 7, 'max_leaf_nodes': 35, 'max_features': 'log2', 'max_samples': 0.8312452276835234}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:09,929] Trial 173 finished with value: 0.5472334682860999 and parameters: {'n_estimators': 102, 'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 12, 'max_leaf_nodes': 34, 'max_features': 'log2', 'max_samples': 0.8676926826701121}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:10,636] Trial 174 finished with value: 0.5473009446693656 and parameters: {'n_estimators': 109, 'max_depth': 5, 'min_samples_split': 19, 'min_samples_leaf': 6, 'max_leaf_nodes': 33, 'max_features': 'log2', 'max_samples': 0.8041910597685064}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:11,533] Trial 175 finished with value: 0.554655870445344 and parameters: {'n_estimators': 131, 'max_depth': 7, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_leaf_nodes': 32, 'max_features': 'log2', 'max_samples': 0.8220152806760513}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:12,309] Trial 176 finished with value: 0.5493252361673415 and parameters: {'n_estimators': 123, 'max_depth': 6, 'min_samples_split': 20, 'min_samples_leaf': 7, 'max_leaf_nodes': 30, 'max_features': 'log2', 'max_samples': 0.780953769401794}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:13,112] Trial 177 finished with value: 0.536774628879892 and parameters: {'n_estimators': 128, 'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 5, 'max_leaf_nodes': 37, 'max_features': 'log2', 'max_samples': 0.7967837409890369}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:13,845] Trial 178 finished with value: 0.5547908232118758 and parameters: {'n_estimators': 113, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 9, 'max_leaf_nodes': 35, 'max_features': 'log2', 'max_samples': 0.8139714675807552}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:14,588] Trial 179 finished with value: 0.5466261808367072 and parameters: {'n_estimators': 117, 'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 8, 'max_leaf_nodes': 36, 'max_features': 'log2', 'max_samples': 0.7625090372793024}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:15,189] Trial 180 finished with value: 0.5211875843454792 and parameters: {'n_estimators': 87, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 11, 'max_leaf_nodes': 38, 'max_features': 'log2', 'max_samples': 0.8512312643071213}. Best is trial 51 with value: 0.5755735492577598.
# [I 2025-03-31 18:43:15,893] Trial 181 finished with value: 0.5756410256410256 and parameters: {'n_estimators': 111, 'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_leaf_nodes': 31, 'max_features': 'sqrt', 'max_samples': 0.8753570807610386}. Best is trial 181 with value: 0.5756410256410256.
# [I 2025-03-31 18:43:16,614] Trial 182 finished with value: 0.5522267206477733 and parameters: {'n_estimators': 111, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_leaf_nodes': 31, 'max_features': 'sqrt', 'max_samples': 0.8789660146354581}. Best is trial 181 with value: 0.5756410256410256.
# [I 2025-03-31 18:43:17,313] Trial 183 finished with value: 0.5393387314439946 and parameters: {'n_estimators': 108, 'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_leaf_nodes': 33, 'max_features': 'sqrt', 'max_samples': 0.8957071320621643}. Best is trial 181 with value: 0.5756410256410256.
# [I 2025-03-31 18:43:17,980] Trial 184 finished with value: 0.552361673414305 and parameters: {'n_estimators': 101, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 10, 'max_leaf_nodes': 30, 'max_features': 'sqrt', 'max_samples': 0.8594853116417432}. Best is trial 181 with value: 0.5756410256410256.
# [I 2025-03-31 18:43:18,706] Trial 185 finished with value: 0.5210526315789474 and parameters: {'n_estimators': 114, 'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 18, 'max_leaf_nodes': 32, 'max_features': 'log2', 'max_samples': 0.8679753235796124}. Best is trial 181 with value: 0.5756410256410256.
# [I 2025-03-31 18:43:19,397] Trial 186 finished with value: 0.508029689608637 and parameters: {'n_estimators': 104, 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 27, 'max_leaf_nodes': 34, 'max_features': 'sqrt', 'max_samples': 0.8875935688677903}. Best is trial 181 with value: 0.5756410256410256.
# [I 2025-03-31 18:43:20,042] Trial 187 finished with value: 0.5547908232118759 and parameters: {'n_estimators': 98, 'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 6, 'max_leaf_nodes': 35, 'max_features': 'log2', 'max_samples': 0.8769296301940205}. Best is trial 181 with value: 0.5756410256410256.
# [I 2025-03-31 18:43:20,804] Trial 188 finished with value: 0.5678137651821863 and parameters: {'n_estimators': 121, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_leaf_nodes': 39, 'max_features': 'log2', 'max_samples': 0.7877266827366757}. Best is trial 181 with value: 0.5756410256410256.
# [I 2025-03-31 18:43:21,570] Trial 189 finished with value: 0.5727395411605938 and parameters: {'n_estimators': 120, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 9, 'max_leaf_nodes': 39, 'max_features': 'log2', 'max_samples': 0.7897659606759683}. Best is trial 181 with value: 0.5756410256410256.
# [I 2025-03-31 18:43:21,999] Trial 190 finished with value: 0.5599865047233469 and parameters: {'n_estimators': 52, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 8, 'max_leaf_nodes': 39, 'max_features': 'log2', 'max_samples': 0.7916250899179704}. Best is trial 181 with value: 0.5756410256410256.
# [I 2025-03-31 18:43:22,765] Trial 191 finished with value: 0.5700404858299596 and parameters: {'n_estimators': 121, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_leaf_nodes': 41, 'max_features': 'log2', 'max_samples': 0.7753307212355651}. Best is trial 181 with value: 0.5756410256410256.
# [I 2025-03-31 18:43:23,541] Trial 192 finished with value: 0.5700404858299596 and parameters: {'n_estimators': 121, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_leaf_nodes': 41, 'max_features': 'log2', 'max_samples': 0.7759910674849582}. Best is trial 181 with value: 0.5756410256410256.
# [I 2025-03-31 18:43:24,298] Trial 193 finished with value: 0.5753036437246963 and parameters: {'n_estimators': 121, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_leaf_nodes': 41, 'max_features': 'log2', 'max_samples': 0.7750713514328347}. Best is trial 181 with value: 0.5756410256410256.
# [I 2025-03-31 18:43:25,061] Trial 194 finished with value: 0.5753036437246963 and parameters: {'n_estimators': 121, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_leaf_nodes': 42, 'max_features': 'log2', 'max_samples': 0.773845296131867}. Best is trial 181 with value: 0.5756410256410256.
# [I 2025-03-31 18:43:25,838] Trial 195 finished with value: 0.5545209176788124 and parameters: {'n_estimators': 121, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 9, 'max_leaf_nodes': 41, 'max_features': 'log2', 'max_samples': 0.754405622162047}. Best is trial 181 with value: 0.5756410256410256.
# [I 2025-03-31 18:43:26,620] Trial 196 finished with value: 0.5700404858299596 and parameters: {'n_estimators': 122, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_leaf_nodes': 40, 'max_features': 'log2', 'max_samples': 0.7753555859603145}. Best is trial 181 with value: 0.5756410256410256.
# [I 2025-03-31 18:43:27,380] Trial 197 finished with value: 0.5805668016194332 and parameters: {'n_estimators': 119, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_leaf_nodes': 42, 'max_features': 'log2', 'max_samples': 0.7739542798761803}. Best is trial 197 with value: 0.5805668016194332.
# [I 2025-03-31 18:43:28,144] Trial 198 finished with value: 0.5805668016194332 and parameters: {'n_estimators': 119, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_leaf_nodes': 42, 'max_features': 'log2', 'max_samples': 0.7732777500868829}. Best is trial 197 with value: 0.5805668016194332.
# [I 2025-03-31 18:43:28,909] Trial 199 finished with value: 0.5727395411605938 and parameters: {'n_estimators': 120, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_leaf_nodes': 42, 'max_features': 'log2', 'max_samples': 0.7787492339409897}. Best is trial 197 with value: 0.5805668016194332.
# Best trial parameters:
# {'n_estimators': 119, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_leaf_nodes': 42, 'max_features': 'log2', 'max_samples': 0.7739542798761803}
# Classification Report (F1 기반 튜닝 + balanced):
#               precision    recall  f1-score   support
#
#            0       0.47      0.55      0.50        98
#            1       0.49      0.41      0.45       105
#
#     accuracy                           0.48       203
#    macro avg       0.48      0.48      0.48       203
# weighted avg       0.48      0.48      0.48       203

# %%
print(f'훈련 데이터: {best_rf.score(X_train_resampled, y_train_resampled)}')
print(f'테스트 데이터: {best_rf.score(X_scaled_test, y_test)}')
print(classification_report(y_test, best_rf.predict(X_scaled_test)))
# Out:
# 훈련 데이터: 0.8652849740932642
# 테스트 데이터: 0.47783251231527096
#               precision    recall  f1-score   support
#
#            0       0.47      0.55      0.50        98
#            1       0.49      0.41      0.45       105
#
#     accuracy                           0.48       203
#    macro avg       0.48      0.48      0.48       203
# weighted avg       0.48      0.48      0.48       203
